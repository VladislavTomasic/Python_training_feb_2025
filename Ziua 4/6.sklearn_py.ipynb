# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression

rezultat=make_regression(n_samples=3, n_features =1, n_targets=1)
print(rezultat,type(rezultat))
# Out:
# (array([[-3.08637441],
#        [-0.91086865],
#        [-1.00883549]]), array([-121.2628969 ,  -35.78780676,  -39.63690004])) <class 'tuple'>

# %%
x,y=rezultat

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
x,y = make_regression(n_samples=3, n_features =1, n_targets=1)
model.fit(x,y)
print(rezultat,type(rezultat))
# Out:
# (array([[-3.08637441],
#        [-0.91086865],
#        [-1.00883549]]), array([-121.2628969 ,  -35.78780676,  -39.63690004])) <class 'tuple'>

# %%
x
# Out:
# array([[ 0.47736856],
#        [ 0.89163838],
#        [-0.48928582]])

# %%
model.predict([[-3.08637441]])
# Out:
# array([-96.4131739])

# %%
plt.scatter(x,y)
plt.show()

# %%
new_x, new_y = x,y = make_regression(n_samples=20, n_features =1, n_targets=1, noise=10)
plt.scatter(new_x,new_y)
plt.show()

# %%
new_model=LinearRegression()
new_model
new_model.fit(new_x,new_y)
predicted_y=new_model.predict(x)

plt.scatter(new_x,new_y)
plt.plot(new_x,predicted_y)
plt.show()
